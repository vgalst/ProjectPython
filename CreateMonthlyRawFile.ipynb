# %%
#Set the modules and bring in the data
import csv
import os
import pandas as pd
import numpy as np
import functools
#Join Conditions
def conjunction(*conditions):
    return functools.reduce(np.logical_and, conditions)
#Kelvin to Fahrenheit conversion
def kelvin_to_fahrenheit(tempereture_kelvin):
   tempereture_fahrenheit = (((tempereture_kelvin - 273) * 9/5) + 32)
   return tempereture_fahrenheit

os.chdir('/Users/macbook/Desktop/Data-Program-Files/Group-Projects/Team-Folder/Raw_Data/')

Yearly_Raw = pd.read_csv("FHV_2018_Raw.csv", parse_dates=[0], low_memory=False)
Yearly_Raw['Pickup_DateTime'] = pd.to_datetime(Yearly_Raw['Pickup_DateTime'])
Yearly_Raw['Month'] = Yearly_Raw['Pickup_DateTime'].apply(lambda x: x.month)

Yearly_Raw.head()
# Out:
#    #     index     Pickup_DateTime     DropOff_datetime  PUlocationID  \
# 0  0  13252281 2018-01-01 00:00:15  2018-01-01 00:23:43          90.0
# 1  1  13223354 2018-01-01 00:00:56  2018-01-01 00:06:41         170.0
# 2  2  13265279 2018-01-01 00:03:12  2018-01-01 00:25:04         188.0
# 3  3  13212712 2018-01-01 00:03:54  2018-01-01 00:17:52          71.0
# 4  4  13251736 2018-01-01 00:04:44  2018-01-01 00:13:57          61.0
#
#    DOlocationID  SR_Flag Dispatching_base_number  Dispatching_base_num  \
# 0          42.0      0.0                  B02835                   0.0
# 1         233.0      0.0                  B02765                   0.0
# 2         210.0      1.0                  B02884                   0.0
# 3          37.0      0.0                  B02510                   0.0
# 4          61.0      0.0                  B02876                   0.0
#
#    Trip_Duration  Month
# 0           23.0      1
# 1            6.0      1
# 2           22.0      1
# ...

# %%
#Extract Data
Var_Jan = Yearly_Raw['Month'] == 1
Jan = Yearly_Raw[conjunction(Var_Jan)]
Jan.to_csv("FHV_2018_Raw_Jan.csv", index=False)

Jan.head()
# Out:
#    #     index     Pickup_DateTime     DropOff_datetime  PUlocationID  \
# 0  0  13252281 2018-01-01 00:00:15  2018-01-01 00:23:43          90.0
# 1  1  13223354 2018-01-01 00:00:56  2018-01-01 00:06:41         170.0
# 2  2  13265279 2018-01-01 00:03:12  2018-01-01 00:25:04         188.0
# 3  3  13212712 2018-01-01 00:03:54  2018-01-01 00:17:52          71.0
# 4  4  13251736 2018-01-01 00:04:44  2018-01-01 00:13:57          61.0
#
#    DOlocationID  SR_Flag Dispatching_base_number  Dispatching_base_num  \
# 0          42.0      0.0                  B02835                   0.0
# 1         233.0      0.0                  B02765                   0.0
# 2         210.0      1.0                  B02884                   0.0
# 3          37.0      0.0                  B02510                   0.0
# 4          61.0      0.0                  B02876                   0.0
#
#    Trip_Duration  Month
# 0           23.0      1
# 1            6.0      1
# 2           22.0      1
# ...

# %%
#Extract Data
Var_Feb = Yearly_Raw['Month'] == 2
Feb = Yearly_Raw[conjunction(Var_Feb)]
Feb.to_csv("FHV_2018_Raw_Feb.csv", index=False)

Feb.head()
# Out:
#            #    index     Pickup_DateTime     DropOff_datetime  PUlocationID  \
# 75856  75856    46643 2018-02-01 00:00:08  2018-02-01 00:06:27         143.0
# 75857  75857    62546 2018-02-01 00:00:10  2018-02-01 00:03:11         108.0
# 75858  75858  2156624 2018-02-01 00:01:21  2018-02-01 00:08:54         181.0
# 75859  75859  2161749 2018-02-01 00:01:55  2018-02-01 00:14:00         142.0
# 75860  75860  2162101 2018-02-01 00:02:55  2018-02-01 00:12:06         100.0
#
#        DOlocationID  SR_Flag Dispatching_base_number  Dispatching_base_num  \
# 75856          48.0      1.0                  B02510                   0.0
# 75857         123.0      1.0                  B02889                   0.0
# 75858         228.0      1.0                  B02877                   0.0
# 75859         170.0      0.0                  B02682                   0.0
# 75860         230.0      0.0                  B02864                   0.0
#
#        Trip_Duration  Month
# ...

# %%
#Extract Data
Var_Mar = Yearly_Raw['Month'] == 3
Mar = Yearly_Raw[conjunction(Var_Mar)]
Mar.to_csv("FHV_2018_Raw_Mar.csv", index=False)

Mar.head()
# Out:
#              #     index     Pickup_DateTime     DropOff_datetime  \
# 150222  150222  18308376 2018-03-01 00:00:36  2018-03-01 00:11:10
# 150223  150223  15308963 2018-03-01 00:01:58  2018-03-01 00:16:26
# 150224  150224  19256949 2018-03-01 00:02:08  2018-03-01 00:10:31
# 150225  150225  15309902 2018-03-01 00:02:28  2018-03-01 00:11:56
# 150226  150226  12586184 2018-03-01 00:02:51  2018-03-01 00:34:11
#
#         PUlocationID  DOlocationID  SR_Flag Dispatching_base_number  \
# 150222          48.0         246.0      0.0                  B02764
# 150223         166.0         235.0      0.0                  B02878
# 150224         255.0          80.0      0.0                  B02395
# 150225         185.0          81.0      0.0                  B02835
# 150226         113.0         265.0      0.0                  B02682
#
#         Dispatching_base_num  Trip_Duration  Month
# 150222                   0.0           11.0      3
# 150223                   0.0           14.0      3
# ...

# %%
#Extract Data
Var_Apr = Yearly_Raw['Month'] == 4
Apr = Yearly_Raw[conjunction(Var_Apr)]
Apr.to_csv("FHV_2018_Raw_Apr.csv", index=False)

Apr.head()
# Out:
#              #     index     Pickup_DateTime     DropOff_datetime  \
# 236370  236370  18069442 2018-04-01 00:00:04  2018-04-01 00:12:42
# 236371  236371  16765785 2018-04-01 00:00:13  2018-04-01 00:14:26
# 236372  236372  16587914 2018-04-01 00:00:19  2018-04-01 00:26:34
# 236373  236373  16609630 2018-04-01 00:00:42  2018-04-01 00:05:29
# 236374  236374  18189328 2018-04-01 00:00:44  2018-04-01 00:14:01
#
#         PUlocationID  DOlocationID  SR_Flag Dispatching_base_number  \
# 236370          65.0          40.0      1.0                  B02866
# 236371         244.0         235.0      0.0                  B02617
# 236372         141.0         148.0      1.0                  B02875
# 236373         246.0         246.0      0.0                  B02879
# 236374         159.0         169.0      1.0                  B02869
#
#         Dispatching_base_num  Trip_Duration  Month
# 236370                   0.0           13.0      4
# 236371                   0.0           14.0      4
# ...

# %%
#Extract Data
Var_May = Yearly_Raw['Month'] == 5
May = Yearly_Raw[conjunction(Var_May)]
May.to_csv("FHV_2018_Raw_May.csv", index=False)

May.head()
# Out:
#              #     index     Pickup_DateTime     DropOff_datetime  \
# 320182  320182   2390527 2018-05-01 00:00:17  2018-05-01 00:13:25
# 320183  320183  10042104 2018-05-01 00:00:28  2018-05-01 00:15:51
# 320184  320184   3405987 2018-05-01 00:00:46  2018-05-01 00:03:21
# 320185  320185   7711482 2018-05-01 00:01:33  2018-05-01 00:22:22
# 320186  320186   3428611 2018-05-01 00:02:04  2018-05-01 00:07:16
#
#         PUlocationID  DOlocationID  SR_Flag Dispatching_base_number  \
# 320182          42.0         167.0      0.0                  B02879
# 320183          42.0         213.0      0.0                  B02510
# 320184         223.0         223.0      0.0                  B02875
# 320185          90.0          80.0      1.0                  B02764
# 320186         114.0         137.0      0.0                  B02872
#
#         Dispatching_base_num  Trip_Duration  Month
# 320182                   0.0           13.0      5
# 320183                   0.0           15.0      5
# ...

# %%
#Extract Data
Var_Jun = Yearly_Raw['Month'] == 6
Jun = Yearly_Raw[conjunction(Var_Jun)]
Jun.to_csv("FHV_2018_Raw_Jun.csv", index=False)

Jun.head()
# Out:
#              #    index     Pickup_DateTime     DropOff_datetime  \
# 405892  405892  4964362 2018-06-01 00:00:30  2018-06-01 00:45:03
# 405893  405893  2758389 2018-06-01 00:00:38  2018-06-01 00:22:40
# 405894  405894   166542 2018-06-01 00:00:56  2018-06-01 00:44:20
# 405895  405895   166591 2018-06-01 00:01:23  2018-06-01 00:12:52
# 405896  405896  3624184 2018-06-01 00:03:29  2018-06-01 00:36:17
#
#         PUlocationID  DOlocationID  SR_Flag Dispatching_base_number  \
# 405892         249.0         189.0      1.0                  B02876
# 405893         163.0         265.0      0.0                  B02878
# 405894         234.0         180.0      0.0                  B02510
# 405895         223.0         146.0      0.0                  B02510
# 405896         254.0         235.0      1.0                  B02764
#
#         Dispatching_base_num  Trip_Duration  Month
# 405892                   0.0           45.0      6
# 405893                   0.0           22.0      6
# ...

# %%
#Extract Data
Var_Jul = Yearly_Raw['Month'] == 7
Jul = Yearly_Raw[conjunction(Var_Jul)]
Jul.to_csv("FHV_2018_Raw_Jul.csv", index=False)

Jul.head()
# Out:
#              #    index     Pickup_DateTime     DropOff_datetime  \
# 490409  490409   443123 2018-07-01 00:00:08  2018-07-01 00:38:24
# 490410  490410  5859645 2018-07-01 00:00:47  2018-07-01 00:04:05
# 490411  490411  2005699 2018-07-01 00:01:05  2018-07-01 00:08:23
# 490412  490412  1347007 2018-07-01 00:01:05  2018-07-01 00:13:01
# 490413  490413  3344961 2018-07-01 00:01:14  2018-07-01 00:48:37
#
#         PUlocationID  DOlocationID  SR_Flag Dispatching_base_number  \
# 490409         249.0         243.0      1.0                  B02800
# 490410         148.0         148.0      1.0                  B02875
# 490411         127.0         244.0      0.0                  B02617
# 490412         142.0          68.0      1.0                  B02800
# 490413         246.0         122.0      0.0                  B02395
#
#         Dispatching_base_num  Trip_Duration  Month
# 490409                   0.0           38.0      7
# 490410                   0.0            3.0      7
# ...

# %%
#Extract Data
Var_Aug = Yearly_Raw['Month'] == 8
Aug = Yearly_Raw[conjunction(Var_Aug)]
Aug.to_csv("FHV_2018_Raw_Aug.csv", index=False)

Aug.head()
# Out:
#              #    index     Pickup_DateTime     DropOff_datetime  \
# 578503  578503  3772325 2018-08-01 00:01:35  2018-08-01 00:45:15
# 578504  578504  1954072 2018-08-01 00:02:24  2018-08-01 00:25:36
# 578505  578505  4390831 2018-08-01 00:02:45  2018-08-01 00:14:08
# 578506  578506  4121240 2018-08-01 00:02:48  2018-08-01 00:07:27
# 578507  578507  4195646 2018-08-01 00:04:11  2018-08-01 00:15:11
#
#         PUlocationID  DOlocationID  SR_Flag Dispatching_base_number  \
# 578503         231.0         152.0      1.0                  B02866
# 578504          33.0          17.0      0.0                  B02682
# 578505         227.0         227.0      0.0                  B02882
# 578506         168.0         159.0      0.0                  B02883
# 578507          79.0         249.0      0.0                  B02884
#
#         Dispatching_base_num  Trip_Duration  Month
# 578503                   0.0           44.0      8
# 578504                   0.0           23.0      8
# ...

# %%
#Extract Data
Var_Sep = Yearly_Raw['Month'] == 9
Sep = Yearly_Raw[conjunction(Var_Sep)]
Sep.to_csv("FHV_2018_Raw_Sep.csv", index=False)

Sep.head()
# Out:
#              #    index     Pickup_DateTime     DropOff_datetime  \
# 668462  668462  2815750 2018-09-01 00:00:10  2018-09-01 00:27:41
# 668463  668463  2422326 2018-09-01 00:00:26  2018-09-01 00:03:32
# 668464  668464  3062750 2018-09-01 00:00:33  2018-09-01 00:14:16
# 668465  668465  3290388 2018-09-01 00:00:33  2018-09-01 00:36:44
# 668466  668466  2112802 2018-09-01 00:00:48  2018-09-01 00:13:53
#
#         PUlocationID  DOlocationID  SR_Flag Dispatching_base_number  \
# 668462         215.0         255.0      0.0                  B02869
# 668463         144.0         114.0      0.0                  B02764
# 668464         126.0          81.0      1.0                  B02877
# 668465          14.0         265.0      0.0                  B02883
# 668466         229.0          79.0      0.0                  B02835
#
#         Dispatching_base_num  Trip_Duration  Month
# 668462                   0.0           28.0      9
# 668463                   0.0            3.0      9
# ...

# %%
#Extract Data
Var_Oct = Yearly_Raw['Month'] == 10
Oct = Yearly_Raw[conjunction(Var_Oct)]
Oct.to_csv("FHV_2018_Raw_Oct.csv", index=False)

Oct.head()
# Out:
#              #    index     Pickup_DateTime     DropOff_datetime  \
# 758729  758729   135745 2018-10-01 00:00:05  2018-10-01 00:12:38
# 758730  758730  3120765 2018-10-01 00:00:09  2018-10-01 00:20:42
# 758731  758731  1395146 2018-10-01 00:00:46  2018-10-01 00:12:22
# 758732  758732  2849390 2018-10-01 00:01:15  2018-10-01 00:14:01
# 758733  758733  3127949 2018-10-01 00:01:21  2018-10-01 00:26:42
#
#         PUlocationID  DOlocationID  SR_Flag Dispatching_base_number  \
# 758729          79.0          48.0      0.0                  B02682
# 758730         122.0         216.0      0.0                  B02884
# 758731          80.0          49.0      1.0                  B02510
# 758732         163.0         140.0      1.0                  B02800
# 758733         106.0          91.0      1.0                  B02836
#
#         Dispatching_base_num  Trip_Duration  Month
# 758729                   0.0           13.0     10
# 758730                   0.0           21.0     10
# ...

# %%
#Extract Data
Var_Nov = Yearly_Raw['Month'] == 11
Nov = Yearly_Raw[conjunction(Var_Nov)]
Nov.to_csv("FHV_2018_Raw_Nov.csv", index=False)

Nov.head()
# Out:
#              #    index     Pickup_DateTime     DropOff_datetime  \
# 853735  853735  9569042 2018-11-01 00:00:18  2018-11-01 00:36:43
# 853736  853736  7414421 2018-11-01 00:00:27  2018-11-01 00:05:35
# 853737  853737  3252567 2018-11-01 00:00:32  2018-11-01 00:06:01
# 853738  853738  3252611 2018-11-01 00:00:55  2018-11-01 00:16:20
# 853739  853739  1739370 2018-11-01 00:00:56  2018-11-01 00:25:36
#
#         PUlocationID  DOlocationID  SR_Flag Dispatching_base_number  \
# 853735          48.0          53.0      0.0                  B02765
# 853736         165.0         165.0      0.0                  B02617
# 853737          61.0          62.0      0.0                  B02510
# 853738          37.0          80.0      0.0                  B02510
# 853739         226.0         197.0      1.0                  B02876
#
#         Dispatching_base_num  Trip_Duration  Month
# 853735                   0.0           36.0     11
# 853736                   0.0            5.0     11
# ...

# %%
#Extract Data
Var_Dec = Yearly_Raw['Month'] == 12
Dec = Yearly_Raw[conjunction(Var_Dec)]
Dec.to_csv("FHV_2018_Raw_Dec.csv", index=False)

Dec.head()
# Out:
#              #    index     Pickup_DateTime     DropOff_datetime  \
# 947310  947310  2335653 2018-12-01 00:00:00  2018-12-01 00:41:27
# 947311  947311  5032538 2018-12-01 00:00:24  2018-12-01 00:48:55
# 947312  947312  4448659 2018-12-01 00:00:28  2018-12-01 00:09:10
# 947313  947313  2014476 2018-12-01 00:00:53  2018-12-01 00:16:45
# 947314  947314  2916146 2018-12-01 00:00:56  2018-12-01 00:29:09
#
#         PUlocationID  DOlocationID  SR_Flag Dispatching_base_number  \
# 947310           4.0          80.0      1.0                  B02800
# 947311         142.0          17.0      0.0                  B02764
# 947312         232.0          79.0      0.0                  B02395
# 947313         162.0         107.0      0.0                  B02869
# 947314         213.0          69.0      1.0                  B02871
#
#         Dispatching_base_num  Trip_Duration  Month
# 947310                   0.0           41.0     12
# 947311                   0.0           49.0     12
# ...
