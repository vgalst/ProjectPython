# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

# %%
#import data from CSV to panda
pie_pickup = ('/Users/Ramahi/Desktop/Project1_File/RideShare_Data_201801.csv')
pie_one_df = pd.read_csv(pie_pickup)
pie_one_df.head()
# Out:
#        Pickup_DateTime     DropOff_datetime  PUlocationID  DOlocationID  \
# 0  2018-01-01 22:22:03  2018-01-01 22:44:48         205.0          63.0
# 1  2018-01-01 12:44:06  2018-01-01 13:12:08         125.0          93.0
# 2  2018-01-01 00:28:16  2018-01-01 00:41:23          39.0          71.0
# 3  2018-01-01 02:42:55  2018-01-01 02:56:46         100.0         137.0
# 4  2018-01-01 14:15:46  2018-01-01 14:37:55          55.0         115.0
#
#    SR_Flag                  Pickup_City                          Dropoff_City  \
# 0      1.0         Saint Albans, Queens               Cypress Hills, Brooklyn
# 1      0.0         Hudson Sq, Manhattan  Flushing Meadows-Corona Park, Queens
# 2      1.0           Canarsie, Brooklyn      East Flatbush/Farragut, Brooklyn
# 3      0.0  Garment District, Manhattan                   Kips Bay, Manhattan
# 4      0.0       Coney Island, Brooklyn    Grymes Hill/Clifton, Staten Island
#
# ...

# %%
#groupby ZIPCode
zip_groups = pie_one_df.groupby(['Pickup_ZipCode'])
zip_groups.head()
#Count # of Rides in a certain ZipCode
#rides_in_zip = zip_groups.count()

#rides_in_zip
# Out:
#             Pickup_DateTime     DropOff_datetime  PUlocationID  DOlocationID  \
# 0       2018-01-01 22:22:03  2018-01-01 22:44:48         205.0          63.0
# 1       2018-01-01 12:44:06  2018-01-01 13:12:08         125.0          93.0
# 2       2018-01-01 00:28:16  2018-01-01 00:41:23          39.0          71.0
# 3       2018-01-01 02:42:55  2018-01-01 02:56:46         100.0         137.0
# 4       2018-01-01 14:15:46  2018-01-01 14:37:55          55.0         115.0
# 5       2018-01-01 04:44:39  2018-01-01 05:01:29           7.0         244.0
# 6       2018-01-01 02:39:44  2018-01-01 02:48:16         144.0         249.0
# 7       2018-01-01 03:46:04  2018-01-01 03:51:51         246.0          68.0
# 8       2018-01-01 05:34:02  2018-01-01 05:39:42         130.0         215.0
# 9       2018-01-01 13:59:46  2018-01-01 14:09:11          49.0          65.0
# 10      2018-01-01 03:45:05  2018-01-01 03:59:21         164.0          87.0
# ...

# %%
#Count # of Rides in a certain ZipCode
rides_in_zip = zip_groups["SR_Flag"].count()

rides_in_zip
NOM_OF_RIDES = rides_in_zip.tolist()
NOM_OF_RIDES
# Out:
# [45,
#  4654,
#  3879,
#  56,
#  3317,
#  1236,
#  2466,
#  2811,
#  2125,
#  2198,
#  85504,
#  1031,
#  610,
#  1279,
#  5352,
#  532,
#  121,
#  174,
#  1546,
#  41,
#  146,
#  2424,
#  745,
#  1119,
#  161,
#  14677,
#  44,
#  411,
#  763,
#  348,
#  569,
#  495,
#  1954,
#  1206,
#  192,
#  37,
#  2609,
#  57829,
#  694,
#  375,
#  17,
#  685,
#  250,
#  2059,
#  31805,
#  2,
#  2495,
#  405,
#  571,
#  428,
#  4]

# %%
#SR_Flags=[]
#=[]
#colors = ["",""]
#explode = (,)

# %%
# Tell matplotlib to create a pie chart based upon the above data
plt.pie(NOM_OF_RIDES, #explode=explode, labels=['SR_Flags'], colors=colors,
        autopct="%11.1f%%", shadow=True, startangle=170)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#barchart for data

rides_chart = NOM_OF_RIDES.plt['SR_Flags'](kind="bar", title="pick up location by zip code")
rides_chart.set_xlabel("ZipCode")
rides_chart.set_ylabel("Number of rides per zipcode")
plt.show()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-0b8acd70074a> in <module>
#       1 #barchart for data
#       2
# ----> 3 rides_chart = NOM_OF_RIDES.plt['SR_Flags'](kind="bar", title="pick up location by zip code")
#       4 rides_chart.set_xlabel("ZipCode")
#       5 rides_chart.set_ylabel("Number of rides per zipcode")
#
# AttributeError: 'list' object has no attribute 'plt'
